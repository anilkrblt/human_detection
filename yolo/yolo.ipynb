# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
model.train(
    data='data.yaml',
    epochs=20,
    imgsz=640,
    batch=16,
    workers=4,
    cache=True,
    name='person_det'
)
# Out:
# Ultralytics 8.3.121  Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# ...

# %%
from ultralytics import YOLO

# 1) Modeli yükleyin
from ultralytics import YOLO

model = YOLO('runs/detect/person_det4/weights/best.pt')

#metrics = model.val(  # DetMetrics objesi döner
#    data='data.yaml',
#    imgsz=640,
#    conf=0.25,
#    iou=0.45
#)

# %%
import cv2
# inference by file
results = model.predict(source="BARİS.jpg", conf=0.2, save=False)
annot = results[0].plot()[..., ::-1]
cv2.imshow("YOLO Detection", annot)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\Users\ACER\Desktop\human_detection\yolo\BARS.jpg: 384x640 3 persons, 53.2ms
# Speed: 9.1ms preprocess, 53.2ms inference, 222.5ms postprocess per image at shape (1, 3, 384, 640)
